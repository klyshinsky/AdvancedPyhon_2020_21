# %% [markdown]
# <p>Для начала пройдем немного теории.</p>
# <p>Все методы оптимизации делятся на методы :<br>
# - одномерной и многомерной оптимизации;<br>
# - градиентной оптимизации и прямые методы; <br>
# - стохастические и детерминированные;<br>
# - поиска локального и глобального минимума; <br>
# - условной и безусловной оптимизации; <br>
# - ...<br>
# </p>
# <p>Традиционно говорят о решении задачи поиска минимума, так как задача поиска максимума сводится к поиску минимума путем смены знака.</p>
# <p>Самым простым методом поиска минимума функции в заданном интервале является <a href="https://ru.wikipedia.org/wiki/%D0%9C%D0%B5%D1%82%D0%BE%D0%B4_%D0%BF%D0%B5%D1%80%D0%B5%D0%B1%D0%BE%D1%80%D0%B0">метод перебора</a>. К его достоинствам можно отнести тот факт, что он находит глобальный (а не локальный) <a href="https://ru.wikipedia.org/wiki/%D0%AD%D0%BA%D1%81%D1%82%D1%80%D0%B5%D0%BC%D1%83%D0%BC">экстремум</a> на заданном интервале. К недостаткам относится снижение точности и большая вычислительная затратность. </p>
# <p>Практически все методы одномерной оптимизации (<a href="https://math.semestr.ru/optim/dichotomy-minimum.php">деления отрезка пополам</a>, <a href="http://www.machinelearning.ru/wiki/images/0/05/MOMO14_min1d.pdf">золотого сечения</a>, <a href="https://www.intuit.ru/studies/courses/1020/188/lecture/4929?page=2">чисел Фибоначи</a>, ... ) могут быть использованы в многомерной оптимизации при применении <a href="http://www.machinelearning.ru/wiki/index.php?title=%D0%9C%D0%B5%D1%82%D0%BE%D0%B4_%D0%BF%D0%BE%D0%BA%D0%BE%D0%BE%D1%80%D0%B4%D0%B8%D0%BD%D0%B0%D1%82%D0%BD%D0%BE%D0%B3%D0%BE_%D1%81%D0%BF%D1%83%D1%81%D0%BA%D0%B0">метода покоординатного спуска</a>.</p>
# <p>Для работы градиентных методов должна быть возможность рассчитать направление наискорейшего роста функции (градиент). Для решения задачи максимизации минимизации необходимо двигаться в его направлении, для решения задачи минимизации - в противоположном. Среди градиентных методов выделяют метод Ньютона (но он требует знания еще и второй производной), <a href="http://encyclopaedia.bid/%D0%B2%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F/%D0%9C%D0%B5%D1%82%D0%BE%D0%B4_%D0%BD%D0%B0%D0%B8%D1%81%D0%BA%D0%BE%D1%80%D0%B5%D0%B9%D1%88%D0%B5%D0%B3%D0%BE_%D1%81%D0%BF%D1%83%D1%81%D0%BA%D0%B0">метод градиентного спуска</a> (немного о <a href="http://www.machinelearning.ru/wiki/index.php?title=%D0%9C%D0%B5%D1%82%D0%BE%D0%B4_%D0%B3%D1%80%D0%B0%D0%B4%D0%B8%D0%B5%D0%BD%D1%82%D0%BD%D0%BE%D0%B3%D0%BE_%D1%81%D0%BF%D1%83%D1%81%D0%BA%D0%B0">его сложностях</a>), метод <a href="http://encyclopaedia.bid/%D0%B2%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F/%D0%9C%D0%B5%D1%82%D0%BE%D0%B4_%D1%81%D0%BE%D0%BF%D1%80%D1%8F%D0%B6%D1%91%D0%BD%D0%BD%D1%8B%D1%85_%D0%B3%D1%80%D0%B0%D0%B4%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2">сопряженных градиентов</a> и другие.</p>
# <p>Для работы прямых методов не нужно знание производных от функций (хотя производную можно оценить и численно), но скорость их работы значительно ниже. При этом они позволяют найти минимум для негладких функций. Среди прямых методов выделяют метод <a href="https://ru.wikipedia.org/wiki/%D0%9C%D0%B5%D1%82%D0%BE%D0%B4_%D0%A5%D1%83%D0%BA%D0%B0_%E2%80%94_%D0%94%D0%B6%D0%B8%D0%B2%D1%81%D0%B0">Хука-Дживса</a> и <a href="http://www.machinelearning.ru/wiki/index.php?title=%D0%9C%D0%B5%D1%82%D0%BE%D0%B4_%D0%9D%D0%B5%D0%BB%D0%B4%D0%B5%D1%80%D0%B0-%D0%9C%D0%B8%D0%B4%D0%B0">Нелдера-Мида</a> (<a href="https://www.youtube.com/watch?v=HUqLxHfxWqU">здесь</a> находится его анимация, в <a href="https://en.wikipedia.org/wiki/Nelder%E2%80%93Mead_method">английской Википедии</a> еще анимация, в том чсиле, сложного случая;  вот <a href="https://habr.com/ru/post/332092/">тут</a> объяснение со словами и кодом на Питоне)</p>
# <p>Все описанные выше методы (кроме метода перебора) не гарантируют нахождения глобального минимума. Данный недостаток может быть (а может быть и нет) исправлен применением стохастических методов: <a href="http://encyclopaedia.bid/%D0%B2%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F/%D0%9C%D0%B5%D1%82%D0%BE%D0%B4_%D0%9C%D0%BE%D0%BD%D1%82%D0%B5-%D0%9A%D0%B0%D1%80%D0%BB%D0%BE">Монте-Карло</a> и <a href="https://ru.wikipedia.org/wiki/%D0%93%D0%B5%D0%BD%D0%B5%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B8%D0%B9_%D0%B0%D0%BB%D0%B3%D0%BE%D1%80%D0%B8%D1%82%D0%BC">генетические алгоритмы</a> (<a href="https://habrahabr.ru/post/128704/">здесь</a> дано популярное описание последних, а <a href="https://habrahabr.ru/post/274975/">здесь</a> - описание точности работы первого). На самом деле, оба этих метода не гарантируют нахождение глобального экстремума, но шансы что они его найдут могут оаказаться выше.</p>
# <p>На современном этапе развития научной мысли все эти методы <b>не используются</b> для решения сложных оптимизационных задач высокой размерности в связи с высокой затратностью. Хорошо справляются с такими задачами такие современные библиотеки, как <a href="https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Optimizer?hl=ru">TensorFlow</a>. В них используются различные комбинации прямых методов (например, выделение случайного подмножества параметров и оптимизация по нему, переход к следующему подмножеству, повторная оптимизация до достижения оптимума по всем параметрам), прямой поиск производной от сложных функций, <a href="https://ru.wikipedia.org/wiki/CUDA">массовый параллелизм</a> и т.д.</p>
#
# <a href="https://habr.com/ru/post/318970/">Здесь</a> можно найти чудестную статью с картинками (и кучей формул), показывающую как работают современные методы.
#
# Так работает метод Нелдера-Мида.
#
# <img src="img/optimization.png">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import minimize
from mpl_toolkits.mplot3d import Axes3D
import random 
from tqdm import tqdm
from copy import copy

# %%
coef=[1, 2, 3]

# Тестовая квадратичная функция.
def simpleFunc(x):
    return sum((x[i]-c)**2 for i, c in enumerate(coef))

x0 = np.array([1.3, 0.7, 0.8])
#rmin = minimize(simpleFunc, x0, method='CG', options={'disp': True})
rmin = minimize(simpleFunc, x0, method='nelder-mead', options={'xtol': 1e-8, 'disp': True})
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 136
#          Function evaluations: 251

# %%
coef=[1, 2, 3]
res, points=[], []

# Тестовая функция, которая запоминает пройденные точки для отображения.
def simpleFunc2(x):
    points.append(x)
    r=sum((x[i]-c)**2 for i, c in enumerate(coef))
    res.append(r)
    return r

# %%
# Функция отрисовки пройденного пути.
def drawPoints3D(points, res, title):
    points2, res2=np.array(points), np.array(res)
    fig = plt.figure(1, figsize=(8, 6))
    ax = Axes3D(fig, elev=-150, azim=110)
    ax.scatter(points2[:, 0], points2[:, 1], points2[:, 2], c=res2, \
               cmap=plt.cm.Set1, edgecolor='k', s=40)
    ax.set_title(title)

    plt.show()

# %%
# Оптимизируем еще раз, отрисовываем пройденный маршрут оптимизации.
x0 = np.array([1.3, 0.7, 0.8])
res, points=[], []
#rmin = minimize(simpleFunc2, x0, method='CG')
rmin = minimize(simpleFunc2, x0, method='nelder-mead', options={'xtol': 1e-8})
print(rmin)
print("Iterantions done:", len(points))
drawPoints3D(points, res, "Nelder-Mead")
# Out:
#  final_simplex: (array([[1.        , 2.        , 3.        ],
#        [1.        , 1.99999999, 3.        ],
#        [1.        , 2.00000001, 3.        ],
#        [0.99999999, 2.        , 3.        ]]), array([1.92962127e-17, 5.15749665e-17, 5.50465262e-17, 6.72851352e-17]))
#            fun: 1.9296212692309132e-17
#        message: 'Optimization terminated successfully.'
#           nfev: 251
#            nit: 136
#         status: 0
#        success: True
#              x: array([1., 2., 3.])
# Iterantions done: 251
# <img src="data:image/png;base64,..." width="1065.75">

# %%
# Функция откланяется в случайную сторону по всем координатам в заданном интервале.
# Отклонение одинаково для всех координат.
def myRandomSearch(func, x0, iterations = 100, delta = 0.1):
    res.append(func(x0))
    points.append(x0)
    x = copy(x0)
    for i in range(iterations):
        for j in range(len(x0)):
            x[j] += random.random() * 2 * delta - delta
        #print(x)
        res.append(func(x))
        points.append(copy(x))
    return res[-1], x
        
res, points=[], []
print(myRandomSearch(simpleFunc, x0, 250))
drawPoints3D(points, res, "Random Changes")
# Out:
# (8.748523716834622, array([ 0.63946597, -0.82984036,  2.21862784]))
# <img src="data:image/png;base64,..." width="1065.75">

# %%
# Функция откланяется в случайную сторону по всем координатам в заданном интервале.
# Отклонение одинаково для всех координат.
def myRandomSearch2(func, x0, iterations = 100, delta = 0.1):
    res.append(func(x0))
    points.append(x0)
    x = copy(x0)
    r_prev = 1e32
    for i in range(iterations):
        x1 = copy(x)
        for j in range(len(x0)):
            x1[j] += random.random() * 2 * delta - delta
        #print(x1)
        r = func(x1)
        #print(x1, r, r_prev)
        if r <= r_prev:
            r_prev = r
            x = x1
        res.append(r)
        points.append(copy(x))
    return r_prev, x
        
res, points=[], []
print(myRandomSearch2(simpleFunc, x0, 250))
drawPoints3D(points, res, "Random Bounded Changes")
# Out:
# (0.00012234771965975356, array([1.00555484, 2.00873337, 2.99609875]))
# <img src="data:image/png;base64,..." width="1065.75">

# %%
# Функция откланяется в случайную сторону по всем координатам в заданном интервале.
# Отклонение происходит с вероятностью 50%, отклонение одинаково по всем координатам.
def myRandomSearch3(func, x0, iterations = 100, delta = 0.1):
    res.append(func(x0))
    points.append(x0)
    x = copy(x0)
    for i in range(iterations):
        for j in range(len(x0)):
            if random.random()>0.5:
                x[j] += random.random() * 2 * delta - delta
        #print(x)
        res.append(func(x))
        points.append(copy(x))
    return res[-1], x
        
res, points=[], []
print(myRandomSearch3(simpleFunc, x0, 250))
drawPoints3D(points, res, "Stochastic Random Changes")
# Out:
# (5.50096107036077, array([1.58565538, 0.24009767, 1.56448175]))
# <img src="data:image/png;base64,..." width="1065.75">

# %%
# Функция откланяется в случайную сторону по всем координатам в заданном интервале.
# Отклонение происходит с вероятностью 50%, отклонение одинаково по всем координатам.
# Отклонение запоминается только при улучшении.
def myRandomSearch4(func, x0, iterations = 100, delta = 0.1, proba = 0.5):
    res.append(func(x0))
    points.append(x0)
    x = copy(x0)
    r_prev = 1e32
    for i in range(iterations):
        x1 = x
        for j in range(len(x0)):
            if random.random() > 0.5:
                x1[j] += random.random() * 2 * delta - delta
        #print(x)
        r = func(x1)
        if r <= r_prev:
            r_prev = r
            x = x1
        res.append(r)
        points.append(copy(x))
    return r_prev, x
        
res, points=[], []
print(myRandomSearch4(simpleFunc, x0, 250))
drawPoints3D(points, res, "Stochastic Bounded Random Changes")
# Out:
# (6.613470249244644, array([0.86602061, 1.16916604, 0.21499677]))
# <img src="data:image/png;base64,..." width="1065.75">

# %%
x0
# Out:
# array([-1.30351859, -0.88710282, -0.62380953])

# %% [markdown]
# Попробуем решить следующую задачу.<br>
# Имеются тексты на пяти языках. Посчитаем статистику встречаемости букв на первом миллионе символов. Далее напишем функцию, которая по методу наименьших квадратов будет определять принадлежность нового текста к одному из языков.<br>

# %%
from collections import Counter

""" Приводит статистику встречаемости stat к относительным значениям.
    stat - словарь, в котором ключами являются буквы, а значениями - частоты.
"""
def normalize(stat):
    s = sum(stat[c] for c in stat.keys())
    return {x : stat[x] / s for x in stat.keys()}

""" Функция определения языка. Считает сумму квадратов отклонений от заранее посчитанных
    распределений для языков. Выбирает язык, для которого сумма минимальна.
    
    text - текст, для которого определяется язык.
    stats - заранее посчитанные распределения.
    
    Возвращает номер языка и значение суммы.
"""
def detectLang(text, stats):
    maxPos = -1
    maxVal = 1e32
    stat = normalize(Counter(text))
    for i, s in enumerate(stats):
        e = sum((s.get(c, 0) - stat[c]) ** 2 for c in stat.keys())
        if e < maxVal:
            maxVal = e
            maxPos = i
    return maxPos, maxVal

""" Находит символ c в списке символов symb в интервале от s до f.
    Возвращает частоту символа или 0, если символ не найден.
"""
def findFreq(c, symb, freq, s, f):
    for i in range(s, f):
        if c == symb[i]:
            return freq[i]
    return 0
    
""" Определяет язык для текста text по частотам символов.
    text - входной текст, для которого определяется язык.
    symbs - набор символов для всех языков.
    freqs - частоты символов.
    positions - интервал, в котором находятся символы и частоты для данного языка.
"""    
def detectLang2(text, symbs, freqs, positions):
    maxPos = -1
    maxVal = 1e32
    stat = normalize(Counter(text))
    for i in range(len(positions) - 1):
        e = sum((findFreq(c, symbs, freqs, positions[i], positions[i + 1]) - stat[c]) ** 2 for c in stat.keys())
#        print(e, maxVal, positions[i], positions[i+1])
        if e < maxVal:
            maxVal = e
            maxPos = i
    return maxPos, maxVal

# Берем файлы с французскими и испанскими новостями, русской фэнтези, англлийским журналом по ИИ, немецкими новостями.
path = '/home/edward/projects/mc&s/utf8/'
filenames = ['le_parisien1_utf8.txt', 'abc-3-es_utf8.txt', 'orcs_and_dwarfs_utf8.txt', 'JMLR.txt', 'bild_utf_8.txt']
files = []
charstats = []

# Считываем первый миллион символов из каждого файла, считаем частоты символов.
for name in filenames:
    file = open(path+name)
    stat = Counter(file.read(1000000))
    stat = normalize(stat)
    files.append(file)
    charstats.append(stat)
#print(charstats[2])

# Считываем из каждого файла следующие 1000 символов, определяем для него язык.
# Просто чтобы посмотреть, что работает.
for i, f in enumerate(files):
    t = f.read(1000)
    n, v = detectLang(t, charstats)
    if n != i:
        print('Negative: ', n, v)
    else:
        print('Positive: ', n, v)

evtexts = []
chars = []
vals = []
positions = [0]

# Для каждого файла считываем 100 фрагментов по 1000 символов.
# Подготавливаем списки символов и частот, запоминаем позиции для языков.
for i, f in enumerate(files):
    evtext = []
    for j in range(100):
        evtext.append(f.read(1000))
    evtexts.append(evtext)
    for c in charstats[i].keys():
        chars.append(c)
        vals.append(charstats[i][c])
    positions.append(positions[i] + len(list(charstats[i].keys())))
    
""" Функция для оценки точности работы метода. 
"""
def evaluate(freqs):
    mistakes = 0
    ra = []
    for i, l in enumerate(evtexts):
        mistakes_cl = 0
        for t in l:
            n, v = detectLang2(t, chars, freqs, positions)
#            print(n, i, v)
            if n != i:
                mistakes += 1
                mistakes_cl += 1
        ra.append(mistakes_cla)
        
    ra.append(mistakes)
    res_all.append(ra)
    print(mistakes)
    return mistakes
    
evaluate(vals)
# Out:
# Positive:  0 0.001724666304999999
# Positive:  1 0.001177448226
# Positive:  2 0.0017983405530000017
# Positive:  3 0.004184306176999998
# Positive:  4 0.015100832799
# 60
# 60

# %%
# Посчитанные частоты.
vals
# Out:
# [0.214855,
#  0.003399,
#  0.101369,
#  0.054876,
#  0.010203,
#  0.000135,
#  0.040219,
#  0.002939,
#  0.002854,
#  0.017799,
#  0.055615,
#  0.0279,
#  0.001087,
#  0.036799,
#  0.002112,
#  0.03623,
#  0.045959,
#  0.002176,
#  0.005511,
#  0.050287,
#  0.016078,
#  0.001665,
#  0.049914,
#  0.051472,
#  0.005875,
#  0.019015,
#  0.017323,
#  0.000907,
#  0.000364,
#  0.000219,
#  0.002369,
#  0.010527,
#  0.001933,
#  0.002199,
#  0.006941,
#  0.002632,
#  0.021563,
#  0.006339,
#  0.006976,
#  0.00105,
#  0.000561,
#  0.008209,
#  0.002431,
#  0.001433,
#  0.003072,
#  0.00846,
#  0.001392,
#  0.001131,
#  0.000958,
#  0.000749,
#  0.00092,
#  0.001097,
#  0.000218,
#  0.000261,
#  0.000874,
#  0.003419,
#  0.000479,
#  0.000804,
#  0.001326,
#  0.001328,
#  0.001105,
#  0.000685,
#  2e-06,
#  4.3e-05,
#  0.000635,
#  0.000681,
#  0.000694,
#  0.002155,
#  0.002873,
#  0.001083,
#  0.002558,
#  0.000663,
#  0.000166,
#  0.000141,
#  0.00049,
#  0.000229,
#  0.000788,
# ...

# %%
len(vals)
# Out:
# 727

# %% [markdown]
# Как видно, ошибка допускается на 60 файлах из 500.
#
# Размерность пространства - 727.
#
# Теперь запустим оптимизационную задачу на пространстве значений частот с тем, чтобы уменьшить количество файлов, на которых достигается ошибка. Из результатов расчета ниже можно увидеть, что сократить ошибку с использованием метода Нелдера-Мида вполне возможно. Правда, остается непроверенным гипотеза о переобучении.

# %%
res = []

rmin = minimize(evaluate, vals, method='nelder-mead', options={"maxiter" : 250})
# Out:
# 60
# 65
# 60
# 58
# 60
# 60
# 60
# 59
# 60
# 60
# 60
# 59
# 59
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 59
# 60
# 60
# 60
# 59
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 59
# 60
# 60
# 59
# 60
# 61
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# ...

# %% [markdown]
# Нет, Нелдер-Мид работает слишком долго, его пришлось остановить.
#
# Теперь попробуем оптимизировать случайным образом.

# %%
        
res, points=[], []
myRandomSearch(evaluate, vals, 250)
# Out:
# 60
# 469
# 492
# 472
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 499
# 500
# 486
# 474
# 477
# 451
# 471
# 467
# 421
# 433
# 430
# 446
# 448
# 491
# 494
# 495
# 496
# 500
# 500
# 500
# 499
# 499
# 500
# 500
# 500
# 499
# 500
# 500
# 500
# 500
# 500
# 500
# 498
# 498
# 492
# 495
# 498
# 499
# 499
# 499
# 497
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# ...

# %% [markdown]
# Тоже слишком долго, и тоже пришлось остановить.
#
# Функция улетела куда-то очень далеко. Но это и не удивительно. Значения у нас в районе 10е-5, а шаг 10е-1. Давайте попробуем уменьшить максимальный шаг до 10е-4.

# %%
res, points=[], []
myRandomSearch(evaluate, vals, 250, 0.0001)
# Out:
# 60
# 60
# 60
# 61
# 60
# 61
# 61
# 60
# 61
# 61
# 61
# 61
# 61
# 60
# 61
# 61
# 61
# 60
# 60
# 60
# 60
# 60
# 60
# 59
# 59
# 60
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 60
# 60
# 60
# 60
# 60
# 60
# 59
# 59
# 60
# 60
# 60
# 59
# 59
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 60
# 59
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 59
# 59
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 61
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 61
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 61
# 61
# 61
# 61
# 61
# 60
# 60
# ...

# %% [markdown]
# На этом прогоне нам откровенно повезло. В общем случае - получалось иногда, но не так хорошо, как хотелось бы. Попробуем управляемое случайное блуждание, которое всегда старается улучшить результат.

# %%
res, points=[], []
myRandomSearch2(evaluate, vals, 1000, 0.0001)
# Out:
# 60
# 60
# 60
# 60
# 60
# 60
# 59
# 60
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 60
# 59
# 60
# 59
# 59
# 60
# 60
# 59
# 59
# 60
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 60
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 60
# 59
# 59
# 59
# 59
# 59
# 60
# 59
# 59
# 59
# 60
# 60
# 59
# 59
# 59
# 60
# 59
# 59
# 59
# 60
# 60
# 59
# 59
# 59
# 59
# 59
# 60
# 59
# 60
# 60
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# ...

# %% [markdown]
# Попробуем теперь с управляемым блужданием, когда мы переходим в новую точку только тогда, когда она не хуже.

# %%
res, points=[], []
myRandomSearch3(evaluate, vals, 1000, 0.0001)
# Out:
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 59
# 59
# 59
# 60
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 60
# 60
# 59
# 59
# 59
# 59
# ...

# %% [markdown]
# А теперь возьмем только часть изменяющихся параметров.

# %%
res, points=[], []
myRandomSearch4(evaluate, vals, 1000, 0.0001)
# Out:
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 61
# 61
# 61
# 60
# 61
# 61
# 61
# 61
# 61
# 60
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 60
# 60
# 61
# 61
# 61
# 61
# 60
# 60
# 59
# 59
# 60
# 60
# 60
# 60
# 60
# 59
# 59
# 60
# 60
# 60
# 60
# 61
# 60
# 60
# 60
# 60
# 60
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# ...

# %%
res, points=[], []
myRandomSearch4(evaluate, vals, 1000, 0.0001, 0.01)
# Out:
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 60
# 60
# 59
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 59
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 60
# 60
# 60
# 60
# 61
# 60
# 60
# 60
# 60
# 60
# 59
# 59
# 59
# 59
# 60
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# ...

# %% [markdown]
# <div style='background-color:#FF1122'>Здесь теперь надо научиться быстро считать распределение не по всем буквам. Для этого надо создать матрицу частот для всех документов, предварительно считать сумму для тех параметров, которые не изменяются, а потом добавлять только меняющиеся параметры. Тогда будет считаться быстрее, то есть и оптимизация пойдет быстрее. И тот же Нелдер-Мид начнет считаться быстрее.</div>

# %% [markdown]
# ## Функции потерь

# %% [markdown]
# Пусть $y_i$ - это i-е рассчитанное значение, а $\hat{y_i}$ - это i-е истинное значение. Тогда можно определить следующие функции для оценки точности результатов.
#
# MAE (Mean Absolute Error) - средняя абсолютная ошибка $MAE=\frac{1}{N}\sum \limits_{i=1}^{N}|y_i-\hat{y_i}| $
#
# MAPE - (Mean Absolute Percentage Error) - средняя абсолютная ошибка в процентах $MAPE=\frac{1}{N}\sum \limits_{i=1}^{N}|\frac{y_i-\hat{y_i}}{\hat{y_i}}| $
#
# MSE (Mean Square Error) - среднеквадратичная ошибка $MSE=\frac{1}{N}\sum \limits_{i=1}^{N}(y_i-\hat{y_i})^2$
#
# RMSE (Root Mean Square Error) - корень из среднеквадратичной ошибки $MSE=\sqrt{MSE}=\sqrt{\frac{1}{N}\sum \limits_{i=1}^{N}(y_i-\hat{y_i})^2}$
#
# RMSLE (Root Mean Square Logarithmic Error) - логарифмическая среднеквадратичная ошибка $RMSLE=\sqrt{\frac{1}{N}\sum \limits_{i=1}^{N}(\log(y_i+1)-\log(\hat{y_i}+1))^2}=\sqrt{\frac{1}{N}\sum \limits_{i=1}^{N}\log^2\left(\frac{y_i+1}{\hat{y_i}+1}\right)}$
#
# RMSPE (Root Mean Square Percentage Error) $RMSPE = \sqrt{MSPE}=\sqrt{\frac{1}{N}\sum \limits_{i=1}^{N}(\frac{y_i-\hat{y_i}}{\hat{y_i}})^2}$

# %%
import numpy as np

from sklearn.feature_extraction.text import CountVectorizer

# %%
    size=1000
    with open("data/esp_test.txt") as file:
        data = file.read()
    print(len(data))
    #data = [data[i*size: (i+1)*size] for i in range(int(len(data[:-(len(data) % size)])/size))]
# Out:
# 50000

# %%
#data
len(data) / size
# Out:
# 50.0

# %%
filenames = ["bg", "rus", "rus_orcs", "by", "ukr", "eng", "esp", "fr", "ger", "it", "tur"]

def prepareFile2(filename, size):
    with open(filename) as file:
        data = file.read()
    data = [data[i*size: (i+1)*size] for i in range(int(len(data)/size))]
    vectors = []
    for dat in data:
        stat = Counter(dat)
        stat = normalize(stat)
        vectors.append(stat)
    return vectors

block_size = 1000
charstats = []
for file in filenames:
    with open(f"data/{file}.txt") as file:
        data = file.read()
    stat = Counter(data)
    stat = normalize(stat)
    charstats.append(stat)
    
test_blocks = []
for file in filenames:
    d = prepareFile2(f"data/{file}_test.txt", block_size)
    test_blocks.append(d)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-6294eb392c1c> in <module>
#      23 for file in filenames:
#      24     d, v = prepareFile(f"data/{file}_test.txt", block_size)
# ---> 25     d = normalize(d)
#      26     test_blocks.append(d)
#      27     test_vectorizers.append(v)
#
# <ipython-input-10-a09cbdffdefe> in normalize(stat)
#       5 """
#       6 def normalize(stat):
# ----> 7     s = sum(stat[c] for c in stat.keys())
#       8     return {x : stat[x] / s for x in stat.keys()}
#       9
#
# /usr/local/lib/python3.6/dist-packages/scipy/sparse/base.py in __getattr__(self, attr)
#     689             return self.getnnz()
#     690         else:
# --> 691             raise AttributeError(attr + " not found")
#     692
#     693     def transpose(self, axes=None, copy=False):
#
# AttributeError: keys not found

# %%
filenames = ["bg", "rus", "rus_orcs", "by", "ukr", "eng", "esp", "fr", "ger", "it", "tur"]

# Берем файлы с французскими и испанскими новостями, русской фэнтези, англлийским журналом по ИИ, немецкими новостями.
charstats = []

# Считываем первый миллион символов из каждого файла, считаем частоты символов.
for name in filenames:
    with open(f"data/{name}.txt") as file:
        stat = Counter(file.read())
        stat = normalize(stat)
        charstats.append(stat)

evtexts = []
chars = []
vals = []
positions = [0]

# Для каждого файла считываем 100 фрагментов по 1000 символов.
# Подготавливаем списки символов и частот, запоминаем позиции для языков.
for i, name in enumerate(filenames):
    with open(f"data/{name}_test.txt") as file:
        data = file.read()
    evtext = [data[i*size: (i+1)*size] for i in range(int(len(data)/size))]
    evtexts.append(evtext)
    for c in charstats[i].keys():
        chars.append(c)
        vals.append(charstats[i][c])
    positions.append(positions[i] + len(list(charstats[i].keys())))

evaluate(vals)

evtexts3 = evtexts
chars3 = chars
vals3 = vals
positions3 = positions

evtexts2 = []
chars2 = []
vals2 = []
positions2 = [0]

# Для каждого файла считываем 100 фрагментов по 1000 символов.
# Подготавливаем списки символов и частот, запоминаем позиции для языков.
for i, name in enumerate(filenames):
    with open(f"data/{name}_test.txt") as file:
        data = file.read()
    evtext = [data[i*size: (i+1)*size] for i in range(int(len(data)/size))]
    evtext = evtext[:50]
    evtexts2.append(evtext)
    for c in charstats[i].keys():
        chars2.append(c)
        vals2.append(charstats[i][c])
    positions2.append(positions[i] + len(list(charstats[i].keys())))

evtexts = evtexts2
chars = chars2
vals = vals2
positions = positions2

evaluate(vals)

evtexts = evtexts3
chars = chars3
vals = vals3
positions = positions3
# Out:
# 52
# 52

# %%
res = []

rmin = minimize(evaluate, vals, method='nelder-mead', options={"maxiter" : 250})
# Out:
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 63
# 53
# 53
# 52
# 52
# 50
# 51
# 51
# 52
# 54
# 53
# 53
# 53
# 52
# 53
# 52
# 52
# 52
# 50
# 50
# 52
# 52
# 53
# 53
# 54
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# ...
